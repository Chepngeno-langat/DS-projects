# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
project_pa = pd.read_csv('/home/karen/Documents/DS-projects/Joy_project_data/PROJECT_PA.csv')

# %%
project_pa
# Out:
#           Name  Age  Gender Status   BMI Transport Engage in PE  \
# 0    E. Gerard   12    male      N  19.3   Vehicle          Yes
# 1   G. Fadhili   11    male      N  15.1   Vehicle          Yes
# 2     T. Waita   11    male      N  15.9   Walking          Yes
# 3   S. Njuguna   12    male     OV  22.0   Vehicle          Yes
# 4     D. Asher   11    male      N  16.4   Vehicle          Yes
# ..         ...  ...     ...    ...   ...       ...          ...
# 86  J. Mwalugo   12  female      N  19.6      Both          Yes
# 87  A. Wachene   13  female      N  21.2   Vehicle          Yes
# 88  V. Wangari   13  female      N  16.9   Vehicle          Yes
# 89   I. Manuli   13  female      N  18.6      Both    Sometimes
# 90   C. Murimi   12  female      N  20.7   Vehicle          Yes
#
#    Other physical activities Video games Personal mobile phone Bikes Football  \
# 0                   Swimming         Yes                   Yes   Yes      Yes
# ...

# %% [markdown]
# ## Data Analysis and Visualization

# %% [markdown]
# #### Gender Distribution

# %%
gender = project_pa['Gender'].value_counts()
# Out:
# Gender
# female    61
# male      30
# Name: count, dtype: int64

# %%
palette_color = sns.color_palette('bright')

labels = ['Female', 'Male']
plt.pie(gender, labels=labels, autopct='%.0f%%')
plt.title('Gender distribution of Students')
plt.show()

# %%
female_df = project_pa[project_pa.Gender=='female']
male_df = project_pa[project_pa.Gender=='male']
female_df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Status', 'BMI', 'Transport', 'Engage in PE',
#        'Other physical activities', 'Video games', 'Personal mobile phone',
#        'Bikes', 'Football', 'Skipping rope'],
#       dtype='object')

# %% [markdown]
# #### Age distribution in students

# %%
female_age = female_df['Age'].value_counts()
plt.figure(figsize=(7, 6))
ax = female_age.plot(kind='bar', rot=0, color='c')
ax.set_title('Age Distribution in female students')
ax.set_xlabel('Age')
ax.set_ylabel('Count')
for rect in ax.patches:
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width()
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value))
    
plt.show()

# %%
male_age = male_df['Age'].value_counts()
plt.figure(figsize=(7, 6))
ax = male_age.plot(kind='bar', rot=0, color='c')
ax.set_title('Age Distribution in male students')
ax.set_xlabel('Age')
ax.set_ylabel('Count')
for rect in ax.patches:
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width()
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value))
    
plt.show()

# %% [markdown]
# #### Status distribution in students

# %%
female_status = female_df['Status'].value_counts()
plt.figure(figsize=(7, 6))
ax = female_status.plot(kind='bar', rot=0, color='c')
ax.set_title('Status Distribution in female students')
ax.set_xlabel('Status')
ax.set_ylabel('Count')
for rect in ax.patches:
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width()
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value))
    
plt.show()

# %%
male_status = male_df['Status'].value_counts()
plt.figure(figsize=(7, 6))
ax = male_status.plot(kind='bar', rot=0, color='c')
ax.set_title('Status Distribution in male students')
ax.set_xlabel('Status')
ax.set_ylabel('Count')
for rect in ax.patches:
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width()
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value))
    
plt.show()

# %% [markdown]
# #### Relationship between BMI and mode of transportation

# %%
ax = sns.barplot(female_df, x='Transport', y='BMI')
ax.set_title('Relationship between BMI and mode of transport used in female students')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(male_df, x='Transport', y='BMI')
ax.set_title('Relationship between BMI and mode of transport used in male students')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %% [markdown]
# #### Relationship between BMI and student engagement is PE

# %%
ax = sns.barplot(female_df, x='Engage in PE', y='BMI')
ax.set_title('Relationship between BMI and student engagement in PE (Female students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(male_df, x='Engage in PE', y='BMI')
ax.set_title('Relationship between BMI and student engagement in PE (male students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
project_pa['Other physical activities'].value_counts()
# Out:
# Other physical activities
# Swimming    32
# Name: count, dtype: int64

# %% [markdown]
# #### Relationship between BMI and whether the student plays video games

# %%
ax = sns.barplot(female_df, x='Video games', y='BMI')
ax.set_title('Relationship between BMI and whether the student plays video games (Female students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(male_df, x='Video games', y='BMI')
ax.set_title('Relationship between BMI and whether the student plays video games (Male students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %% [markdown]
# #### Relationship between BMI and whether the student has a mobile phone

# %%
ax = sns.barplot(project_pa, x='Personal mobile phone', y='BMI')
ax.set_title('Relationship between BMI and whether the student has a mobile phone')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %% [markdown]
# #### Relationship between BMI and whether the student bikes

# %%
ax = sns.barplot(female_df, x='Bikes', y='BMI')
ax.set_title('Relationship between BMI and whether the student Bikes (Female students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(male_df, x='Bikes', y='BMI')
ax.set_title('Relationship between BMI and whether the student Bikes (Male students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %% [markdown]
# #### Relationship between BMI and whether the student plays Football

# %%
ax = sns.barplot(male_df, x='Football', y='BMI')
ax.set_title('Relationship between BMI and whether the student plays football (Male students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(female_df, x='Football', y='BMI')
ax.set_title('Relationship between BMI and whether the student plays football (Female students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %% [markdown]
# #### Relationship between BMI and whether the student skips rope

# %%
ax = sns.barplot(female_df, x='Skipping rope', y='BMI')
ax.set_title('Relationship between BMI and whether the student skips rope (Female students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(male_df, x='Skipping rope', y='BMI')
ax.set_title('Relationship between BMI and whether the student skips rope (Male students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %% [markdown]
# ### Second Dataset

# %%
project_attitudes = pd.read_csv('/home/karen/Documents/DS-projects/Joy_project_data/PROJECT_ATTITUDES.csv')
project_attitudes
# Out:
#           Name  Age  Gender Status   BMI Fat= Healthy Thin= Unhealthy  \
# 0    E. Gerard   12    male      N  19.3            F               T
# 1   G. Fadhili   11    male      N  15.1            F               T
# 2     T. Waita   11    male      N  15.9            F               T
# 3   S. Njuguna   12    male     OV  22.0            F               F
# 4     D. Asher   11    male      N  16.4            F               F
# ..         ...  ...     ...    ...   ...          ...             ...
# 86  J. Mwalugo   12  female      N  19.6            F               F
# 87  A. Wachene   13  female      N  21.2            T               F
# 88  V. Wangari   13  female      N  16.9            T               F
# 89   I. Manuli   13  female      N  18.6            T               T
# 90   C. Murimi   12  female      N  20.7            F               T
#
#    Eat more when emotional Eat less when emotional Rewarded with food  \
# ...

# %% [markdown]
# #### Students attitude on different weights

# %%
Fat = project_attitudes['Fat= Healthy'].value_counts()
Thin = project_attitudes['Thin= Unhealthy'].value_counts()

# %%
palette_color = sns.color_palette('bright')

labels = ['No', 'Yes']
plt.pie(Fat, labels=labels, autopct='%.0f%%')
plt.title('Students attitude on being Fat (Does Fat = Healthy?)')
plt.show()

# %%
palette_color = sns.color_palette('bright')

labels = ['No', 'Yes']
plt.pie(Thin, labels=labels, autopct='%.0f%%')
plt.title('Students attitude on being Fat (Does Thin = Unhealthy?)')
plt.show()

# %%
female_df = project_attitudes[project_attitudes.Gender=='female']
male_df = project_attitudes[project_attitudes.Gender=='male']
female_df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Status', 'BMI', 'Fat= Healthy',
#        'Thin= Unhealthy', 'Eat more when emotional', 'Eat less when emotional',
#        'Rewarded with food', 'Feelings about weight'],
#       dtype='object')

# %% [markdown]
# #### Relationship between BMI and eating habits when emotional

# %%
ax = sns.barplot(female_df, x='Eat more when emotional', y='BMI')
ax.set_title('Relationship between BMI and eating more when emotional (Female students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(female_df, x='Eat less when emotional', y='BMI')
ax.set_title('Relationship between BMI and eating less when emotional (Female students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(male_df, x='Eat more when emotional', y='BMI')
ax.set_title('Relationship between BMI and eating more when emotional (Male students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(male_df, x='Eat less when emotional', y='BMI')
ax.set_title('Relationship between BMI and eating less when emotional (Male students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %% [markdown]
# #### Relationship between BMI and kids being rewarded with food

# %%
ax = sns.barplot(project_attitudes, x='Rewarded with food', y='BMI')
ax.set_title('Relationship between BMI and being rewarded with Food (All students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(female_df, x='Rewarded with food', y='BMI')
ax.set_title('Relationship between BMI and being rewarded with Food (Female students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(male_df, x='Rewarded with food', y='BMI')
ax.set_title('Relationship between BMI and being rewarded with Food (Male students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %% [markdown]
# #### Distribution of students feelings about their weight

# %%
attitude = project_attitudes['Feelings about weight'].value_counts()

# %%
attitude
# Out:
# Feelings about weight
# Okay          71
# Don’t know     9
# Too fat        7
# Too thin       4
# Name: count, dtype: int64

# %%
palette_color = sns.color_palette('bright')

labels = ['Okay', "Don't know", 'Too fat', 'Too thin']
plt.pie(attitude, labels=labels, autopct='%.0f%%')
plt.title('Students feelings about their weight')
plt.show()

# %%
ax = sns.barplot(project_attitudes, x='Feelings about weight', y='BMI')
ax.set_title('Relationship between BMI and students feelings about their weight')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(female_df, x='Feelings about weight', y='BMI')
ax.set_title('Relationship between BMI and students feelings about their weight (Female Students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()

# %%
ax = sns.barplot(male_df, x='Feelings about weight', y='BMI')
ax.set_title('Relationship between BMI and students feelings about their weight (Male Students)')
for rect in ax.patches:
    y_value = round(rect.get_height(), 2)
    x_value = round(rect.get_x() + rect.get_width() , 2)
    space = 1
    label = format(y_value)
    ax.annotate(label, (x_value, y_value), ha='center', va='center')
plt.show()
