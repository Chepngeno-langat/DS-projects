# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv('train.csv', index_col='id')
test_data = pd.read_csv('test.csv', index_col='id')

# %%
train_data
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# id
# 0                 2               0                     0                  2
# 1                 2               0                     1                  2
# 2                 2               0                     0                  1
# 3                 1               0                     0                  2
# 4                 2               0                     1                  0
# ...             ...             ...                   ...                ...
# 42095             3               0                     0                  4
# 42096             2               0                     0                  3
# 42097             2               0                     0                  2
# 42098             1               0                     0                  3
# 42099             2               0                     1                  1
#
# ...

# %%
train_data.dtypes
# Out:
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                         int64
# required_car_parking_space                int64
# room_type_reserved                        int64
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                       int64
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                            int64
# dtype: object

# %%
train_data.shape
# Out:
# (42100, 18)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42100 entries, 0 to 42099
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          42100 non-null  int64
#  1   no_of_children                        42100 non-null  int64
#  2   no_of_weekend_nights                  42100 non-null  int64
#  3   no_of_week_nights                     42100 non-null  int64
#  4   type_of_meal_plan                     42100 non-null  int64
#  5   required_car_parking_space            42100 non-null  int64
#  6   room_type_reserved                    42100 non-null  int64
#  7   lead_time                             42100 non-null  int64
#  8   arrival_year                          42100 non-null  int64
#  9   arrival_month                         42100 non-null  int64
#  10  arrival_date                          42100 non-null  int64
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.barplot(x=train_data['booking_status'] ,y=train_data['no_of_previous_cancellations'])
# Out:
# <AxesSubplot:xlabel='booking_status', ylabel='no_of_previous_cancellations'>

# %%
sns.barplot(x=train_data['booking_status'] ,y=train_data['no_of_adults'])
# Out:
# <AxesSubplot:xlabel='booking_status', ylabel='no_of_adults'>

# %%
sns.barplot(x=train_data['booking_status'] ,y=train_data['required_car_parking_space'])
# Out:
# <AxesSubplot:xlabel='booking_status', ylabel='required_car_parking_space'>

# %%
sns.barplot(x=train_data['booking_status'] ,y=train_data['avg_price_per_room'])
# Out:
# <AxesSubplot:xlabel='booking_status', ylabel='avg_price_per_room'>

# %%
y = train_data['booking_status']
X = train_data.drop('booking_status', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
train_model = DecisionTreeClassifier()
train_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score
print('Training accuracy...', accuracy_score(y_train, train_model.predict(X_train)))
print('Test accuracy...', accuracy_score(y_test, train_model.predict(X_test)))
# Out:
# Training accuracy... 0.9909951430495976
# Test accuracy... 0.7367739149211834

# %%
test_data
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# id
# 42100             3               0                     1                  4
# 42101             2               0                     0                  3
# 42102             2               2                     0                  1
# 42103             2               0                     0                  3
# 42104             1               0                     0                  2
# ...             ...             ...                   ...                ...
# 70163             2               0                     1                  2
# 70164             2               0                     2                  2
# 70165             2               0                     1                  2
# 70166             3               0                     0                  4
# 70167             2               0                     2                  3
#
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28068 entries, 42100 to 70167
# Data columns (total 17 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          28068 non-null  int64
#  1   no_of_children                        28068 non-null  int64
#  2   no_of_weekend_nights                  28068 non-null  int64
#  3   no_of_week_nights                     28068 non-null  int64
#  4   type_of_meal_plan                     28068 non-null  int64
#  5   required_car_parking_space            28068 non-null  int64
#  6   room_type_reserved                    28068 non-null  int64
#  7   lead_time                             28068 non-null  int64
#  8   arrival_year                          28068 non-null  int64
#  9   arrival_month                         28068 non-null  int64
#  10  arrival_date                          28068 non-null  int64
# ...

# %%
test_data_predictions = train_model.predict(test_data)
test_data_predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
test_data_predictions = pd.DataFrame(test_data_predictions)
test_data_predictions.rename({0: 'booking_status'}, axis=1, inplace=True)
test_data_predictions.insert(0, 'id', test_data_predictions.index + 42100)
#test_data_predictions = test_data_predictions.set_index('id')
test_data_predictions
submission_file =(test_data_predictions.to_csv('submission_file.csv',index=False))
